# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
Link = ('https://github.com/Ben-physics-dotcom/Internships/raw/main/FPR-1/Seebeck-Effect/Data/SK-Data.xlsx')
data = pd.ExcelFile(Link)

# %%
sheets = data.sheet_names
print(sheets[0])
print(sheets[5])
# Out:
# Data-for-Ri-sheets
# r1

# %%
df_data_ri = pd.read_excel(data,sheets[0])
df_data_ri = df_data_ri.rename(columns={'Unnamed: 0':'ri'})
df_data_ri.index = df_data_ri['ri']
df_data_ri = df_data_ri.drop(['ri'],axis=1)
df_r1 = pd.read_excel(data,sheets[5])
df_data_ri.head()
# Out:
#     T1 [K]  Sample T [K]  Wanted T [K]  file number      Time  I [A]
# ri
# r0  294.95        295.28           295            1  16-28-41      0
# r1  294.96        295.28           295            1  16-29-08      0
# r2  295.04        295.38           295            1  16-38-26      3
# r3  295.04        295.38           295            1  16-38-53      3
# r4  295.02        295.36           295            1  16-41-59      6

# %%
index = list(df_r1['Unnamed: 0'])
# print(index)
df_r1.index = index
df_r1 = df_r1.drop(['Unnamed: 0'],axis=1)
df_r1.head()
# Out:
#     Current [A]  Volt [V]     Power [W]  Ressistent [R]  Source Delay [s]  \
# 1  0.000000e+00  0.000002  0.000000e+00         0.00000              5.00
# 2  0.000000e+00  0.000002  0.000000e+00         0.00000              1.00
# 3  1.000000e-07  0.000002  2.474188e-13        24.74188              0.01
# 4  2.000000e-07  0.000003  6.431849e-13        16.07962              0.01
# 5  3.000000e-07  0.000004  1.181481e-12        13.12757              0.01
#
#    Volt. Lim. [V]
# 1               1
# 2               1
# 3               1
# 4               1
# 5               1

# %% [markdown]
# # U I Kennlinie
# data: r1

# %%
plt.plot(df_r1['Current [A]']*1e5,df_r1['Volt [V]']*1e5,'ko')
